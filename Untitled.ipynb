# %%
import numpy as np
import pandas as pd
from numpy import sqrt
import matplotlib.pyplot as plt
# %matplotlib inline

vol = .030
lag = 300
df = pd.DataFrame(np.random.randn(100000) * sqrt(vol) * sqrt(1 / 252.)).cumsum()
plt.plot(df[0].tolist());
plt.show();

# %%
import requests
import time
while True:
    a = requests.get('https://timeseries-generator.run.aws-usw02-pr.ice.predix.io/api/v1.0/timeseries').json()
    df = df.append({'timestamp': a['time'],
                    'temp': a['temp'],
                    'volt': a['volt']}, ignore_index=True)
    time.sleep(1.0)
return None
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-7332e1cbdf63> in <module>()
#       6                     'temp': a['temp'],
#       7                     'volt': a['volt']}, ignore_index=True)
# ----> 8     time.sleep(1.0)
#       9 return None
#
# KeyboardInterrupt:

# %%
df
# Out:
# Empty DataFrame
# Columns: [timestamp, temp, volt]
# Index: []

# %%
import numpy as np
import pandas as pd
from numpy import sqrt
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.DataFrame(columns=['timestamp', 'temp', 'volt'])

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [timestamp, temp, volt]
# Index: []

# %%
plt.figure(figsize=(30, 5))
plt.plot('timestamp', 'temp', data=df)
plt.show();

plt.figure(figsize=(30, 5))
plt.plot('timestamp', 'volt', data=df)
plt.show();
